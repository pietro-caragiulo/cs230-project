# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os 
from os.path import dirname
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from DataParser import DataParser
from CsvParser  import CsvParser

# %% [markdown]
# ## Datasets location
#
# Manually type where the signal and background are located

# %%
data_dir        = os.path.join(os.getcwd(), '../datasets')

signal_file_orig     = 'ap_100MeV_L1L1_loose.csv'
background_file_orig = 'tritrig-wab-beam_100MeV_L1L1_loose.csv'

signal_file_02mm     = './2mm/signal_02mm.csv'
background_file_02mm = './2mm/background_02mm.csv'

signal_file_08mm     = './2mm/signal_08mm.csv'
background_file_08mm = './2mm/background_08mm.csv'

signal_file_2mm     = './2mm/signal_2mm.csv'
background_file_2mm = './2mm/background_2mm.csv'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5f9a670bc82e> in <module>
# ----> 1 data_dir        = os.path.join(os.getcwd(), '../datasets')
#       2
#       3 signal_file_orig     = 'ap_100MeV_L1L1_loose.csv'
#       4 background_file_orig = 'tritrig-wab-beam_100MeV_L1L1_loose.csv'
#       5
#
# NameError: name 'os' is not defined

# %% [markdown]
# ## Background, Signal and Data object declaration
#
# CsvParser objects attributes map the CSV structure
# DataParser objects combine the signal and background CsvParser objects, add a label and shuffle the data

# %%
background_orig = CsvParser(os.path.join(data_dir, background_file_orig))
signal_orig     = CsvParser(os.path.join(data_dir, signal_file_orig))

background_02mm = CsvParser(os.path.join(data_dir, background_file_02mm))
signal_02mm     = CsvParser(os.path.join(data_dir, signal_file_02mm))

background_08mm = CsvParser(os.path.join(data_dir, background_file_08mm))
signal_08mm     = CsvParser(os.path.join(data_dir, signal_file_08mm))

background_2mm = CsvParser(os.path.join(data_dir, background_file_2mm))
signal_2mm     = CsvParser(os.path.join(data_dir, signal_file_2mm))

myData_orig     = DataParser(signal=signal_orig, background=background_orig)
myData_02mm     = DataParser(signal=signal_orig, background=background_02mm)
myData_08mm     = DataParser(signal=signal_orig, background=background_08mm)
myData_2mm      = DataParser(signal=signal_orig, background=background_2mm)
# Out:
# [INFO]: Reading CSV file C:\Users\carag\Google Drive\PhD\Classes\CS230\project\repo\cs230-project\notebooks\datasets\tritrig-wab-beam_100MeV_L1L1_loose.csv found 217012 rows and 31 columns
# [INFO]: Found 31 features and 217012 samples
# [INFO]: Filtering data removing these columns ['vx', 'vy', 'vz']
# [INFO]: Cleaning data
# [INFO]: Cleaned 98259 samples
# [INFO]: Reading CSV file C:\Users\carag\Google Drive\PhD\Classes\CS230\project\repo\cs230-project\notebooks\datasets\ap_100MeV_L1L1_loose.csv found 30290 rows and 31 columns
# [INFO]: Found 31 features and 30290 samples
# [INFO]: Filtering data removing these columns ['vx', 'vy', 'vz']
# [INFO]: Cleaning data
# [INFO]: Cleaned 675 samples

# %%
background.RAW_DF
# Out:
#         truthZ        vx        vy       vz    vxPull    vyPull    vzPull  \
# 0            0 -0.005155  0.069285 -0.14702 -0.035926  1.286949 -0.088647
# 1            0  0.126370 -0.026420  2.08232  0.743824 -0.431225  1.092999
# 2            0  0.273907  0.059325 -1.22726  1.345861  0.703793 -0.601704
# 3            0  0.162240  0.006967  2.51526  1.044787  0.108469  1.920790
# 4            0  0.154273  0.115379  0.59679  0.878579  1.579275  0.272066
# ...        ...       ...       ...      ...       ...       ...       ...
# 217007       0  0.215354 -0.007769  1.06975  1.487790 -0.115197  0.495071
# 217008       0  0.573936 -0.025290  1.61910  3.669012 -0.493961  0.930803
# 217009       0 -0.145360 -0.086571 -2.37208 -0.848869 -1.094808 -1.552327
# 217010       0 -0.056261 -0.097727 -3.30387 -0.381696 -1.736933 -2.758652
# 217011       0 -0.006883 -0.133021 -1.20677 -0.038989 -1.802395 -0.695684
#
#            uncP  uncChisq      uncM  ...  eleTrkD0Err  eleTrkTanLambdaErr  \
# 0       2.31702  0.131034  0.102213  ...     0.168361                 0.0
# 1       2.00508  0.886564  0.092945  ...     0.212493                 0.0
# 2       1.52107  5.159340  0.093753  ...     0.303344                 0.0
# 3       1.91684  0.447282  0.093677  ...     0.195003                 0.0
# 4       1.80268  0.474056  0.091857  ...     0.278531                 0.0
# ...         ...       ...       ...  ...          ...                 ...
# 217007  2.00150  1.474350  0.090866  ...     0.268988                 0.0
# 217008  2.29162  8.722720  0.095530  ...     0.214499                 0.0
# 217009  1.63798  6.698260  0.095650  ...     0.222806                 0.0
# 217010  2.38592  0.137313  0.106616  ...     0.180096                 0.0
# 217011  1.73506  0.232526  0.093567  ...     0.245761                 0.0
#
#         eleTrkZ0Err  posChisqDOF  posTrkD0  posTrkTanLambda     posZ0  \
# 0          0.058841     0.950126  0.026123              0.0 -0.120826
# 1          0.076248     0.337988 -0.171040              0.0  0.005494
# 2          0.147102     2.540060  0.670632              0.0  0.158462
# 3          0.083814     1.097172  0.095208              0.0  0.035736
# 4          0.121399     0.573736 -0.112869              0.0 -0.085591
# ...             ...          ...       ...              ...       ...
# 217007     0.137608     1.045194  0.146474              0.0 -0.003259
# 217008     0.060080     1.019636 -0.025929              0.0 -0.333860
# 217009     0.109610     3.436914 -0.179780              0.0  0.150508
# 217010     0.069391     1.501057 -0.390758              0.0 -0.437824
# 217011     0.094653     0.318758  0.080162              0.0 -0.397220
#
#         posTrkD0Err  posTrkTanLambdaErr  posTrkZ0Err
# 0          0.253012                 0.0     0.094608
# 1          0.265175                 0.0     0.097243
# 2          0.242558                 0.0     0.088280
# 3          0.245345                 0.0     0.096153
# 4          0.217496                 0.0     0.080283
# ...             ...                 ...          ...
# 217007     0.168573                 0.0     0.058565
# 217008     0.221309                 0.0     0.090064
# 217009     0.231052                 0.0     0.098935
# 217010     0.224982                 0.0     0.073648
# 217011     0.234724                 0.0     0.101299
#
# [217012 rows x 31 columns]

# %%
background.DATA_DF
# Out:
#               vx        vy       vz  label
# 1       0.126370 -0.026420  2.08232      0
# 3       0.162240  0.006967  2.51526      0
# 4       0.154273  0.115379  0.59679      0
# 6      -0.057568  0.062349  3.21237      0
# 7       0.272659 -0.022014  0.89489      0
# ...          ...       ...      ...    ...
# 217004  0.035849 -0.016170  1.32010      0
# 217005  0.649722 -0.095231  2.11182      0
# 217006 -0.319911 -0.004201  1.53596      0
# 217007  0.215354 -0.007769  1.06975      0
# 217008  0.573936 -0.025290  1.61910      0
#
# [118753 rows x 4 columns]

# %%
background.FILTERED_DF
# Out:
#               vx        vy       vz
# 0      -0.005155  0.069285 -0.14702
# 2       0.273907  0.059325 -1.22726
# 5       0.530340  0.048083 -0.36199
# 8      -0.065597 -0.070985 -3.66406
# 9       0.295010 -0.123345 -2.36196
# ...          ...       ...      ...
# 217000 -0.377327  0.110533 -2.13924
# 217001  0.076519  0.171751 -1.48913
# 217009 -0.145360 -0.086571 -2.37208
# 217010 -0.056261 -0.097727 -3.30387
# 217011 -0.006883 -0.133021 -1.20677
#
# [98259 rows x 3 columns]

# %%
myData.DATA_DF
# Out:
#               vx        vy         vz  label
# 62580  -0.074358 -0.090186   1.934060      0
# 89130   0.181439  0.014883   1.578860      0
# 82491   0.383042  0.104929   0.116970      0
# 25310   0.106339  0.102976   4.061993      0
# 18701   0.079864  0.036078   3.954003      0
# ...          ...       ...        ...    ...
# 133778  0.018848 -0.026327   0.740080      0
# 199808 -0.107167  0.200612   4.287539      0
# 91278   0.117078 -0.161324   0.100930      0
# 9529    0.271752 -0.089822   0.826840      0
# 9520    0.315497 -0.067908  42.191700      1
#
# [148368 rows x 4 columns]

# %% [markdown]
# ## Plot Histograms of Signal and Background
#
# Visually inspect the plots for now to check if the plot label matches between signal and background

# %%
# Set-up picture
fig_row = 6
fig_col = 6
fig, ax = plt.subplots(fig_row, fig_col, figsize=(15,15))
fig.tight_layout()

# Plot background
for i, feature in enumerate(background.CSV_HEADER):    
    thisAx = ax[i % fig_col, i // fig_row]
    _ = thisAx.hist(background.RAW_DF[feature], bins=50, label=feature)
    thisAx.legend()
    thisAx.set_xticks([]) 
    thisAx.set_yticks([])

# Plot signal    
for i, feature in enumerate(signal.CSV_HEADER):    
    thisAx = ax[i % fig_col, i // fig_row]
    _ = thisAx.hist(signal.RAW_DF[feature], bins=50, label=feature)
    thisAx.legend()
    thisAx.set_xticks([]) 
    thisAx.set_yticks([])  
# Remove extra axies
for j in range(i+1, fig_row*fig_col):
    fig.delaxes(ax[j % fig_col, j // fig_row])

plt.show()

# %%
myData

# %%
myData.DATA_DF
# Out:
#               vx        vy         vz  label
# 62580  -0.074358 -0.090186   1.934060      0
# 89130   0.181439  0.014883   1.578860      0
# 82491   0.383042  0.104929   0.116970      0
# 25310   0.106339  0.102976   4.061993      0
# 18701   0.079864  0.036078   3.954003      0
# ...          ...       ...        ...    ...
# 133778  0.018848 -0.026327   0.740080      0
# 199808 -0.107167  0.200612   4.287539      0
# 91278   0.117078 -0.161324   0.100930      0
# 9529    0.271752 -0.089822   0.826840      0
# 9520    0.315497 -0.067908  42.191700      1
#
# [148368 rows x 4 columns]

# %%
df = background.DATA_DF[['vx', 'vy', 'vz']]

# %%
df
# Out:
#               vx        vy       vz
# 1       0.126370 -0.026420  2.08232
# 3       0.162240  0.006967  2.51526
# 4       0.154273  0.115379  0.59679
# 6      -0.057568  0.062349  3.21237
# 7       0.272659 -0.022014  0.89489
# ...          ...       ...      ...
# 217004  0.035849 -0.016170  1.32010
# 217005  0.649722 -0.095231  2.11182
# 217006 -0.319911 -0.004201  1.53596
# 217007  0.215354 -0.007769  1.06975
# 217008  0.573936 -0.025290  1.61910
#
# [118753 rows x 3 columns]

# %%
myData.X.shape
# Out:
# (3, 148368)

# %%
myData.Y.shape
# Out:
# (1, 148368)

# %%
X_train, Y_train, X_test, Y_test, classes = myData.load_dataset()

# %%
X_train.shape[1]+X_test.shape[1]
# Out:
# 148368

# %%
Y_test.shape
# Out:
# (1, 48962)
